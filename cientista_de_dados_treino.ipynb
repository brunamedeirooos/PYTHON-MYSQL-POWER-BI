# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunaMedeiroos/PYTHON-MYSQL-POWER-BI/blob/main/cientista_de_dados_treino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Os dados representam a lista de preços de Medicamentos , contemplando o preço Fábrica, ou preço fabricante (PF), que é o preço máximo que pode ser praticado pelas empresas produtoras ou importadoras do produto e pelas empresas distribuidoras. O PF indica o preço máximo permitido para venda a farmácias e drogarias e o Preço Máximo ao Consumidor (PMC) indica o preço teto de venda ao consumidor.
#
# >Criado em 31 de Maio de 2017, às 14:07

# %%
import pandas as pd

# %%
medicamentos = pd.read_csv('/content/drive/MyDrive/Analista de Dados/DADOS/TA_PRECO_MEDICAMENTO.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
medicamentos
# Out:
#                                               SUBSTÂNCIA  ...              TARJA
# 0      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  ...         Tarja -(*)
# 1                       DIENOGESTE;VALERATO DE ESTRADIOL  ...  Tarja Vermelha(*)
# 2                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 3                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 4                                           MONTELUCASTE  ...    Tarja  Vermelha
# ...                                                  ...  ...                ...
# 26057                                    INSULINA HUMANA  ...  Tarja Vermelha(*)
# 26058                                    INSULINA HUMANA  ...    Tarja  Vermelha
# 26059                                ISOCONAZOL;ABARELIX  ...    Tarja  Vermelha
# 26060                                 VALPROATO DE SÓDIO  ...         Tarja -(*)
# 26061                                    ÁCIDO VALPRÓICO  ...         Tarja -(*)
#
# ...

# %%
medicamentos.head(11)
# Out:
#                                            SUBSTÂNCIA  ...              TARJA
# 0   SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  ...         Tarja -(*)
# 1                    DIENOGESTE;VALERATO DE ESTRADIOL  ...  Tarja Vermelha(*)
# 2              HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 3              HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 4                                        MONTELUCASTE  ...    Tarja  Vermelha
# 5                                        MONTELUCASTE  ...    Tarja  Vermelha
# 6                                        MONTELUCASTE  ...    Tarja  Vermelha
# 7                                        MONTELUCASTE  ...    Tarja  Vermelha
# 8                                        MONTELUCASTE  ...    Tarja  Vermelha
# 9                                        MONTELUCASTE  ...    Tarja  Vermelha
# 10                                       MONTELUCASTE  ...  Tarja Vermelha(*)
#
# [11 rows x 40 columns]

# %%
# esse comando ira mostrar as linhas e colunas
medicamentos.shape
# Out:
# (26062, 40)

# %%
#aqui ira mostrar uma coluna
medicamentos.columns
# Out:
# Index(['SUBSTÂNCIA', 'CNPJ', 'LABORATÓRIO', 'CÓDIGO GGREM', 'REGISTRO',
#        'EAN 1', 'EAN 2', 'EAN 3', 'PRODUTO', 'APRESENTAÇÃO',
#        'CLASSE TERAPÊUTICA', 'TIPO DE PRODUTO (STATUS DO PRODUTO)',
#        'REGIME DE PREÇO', 'PF Sem Impostos', 'PF 0%', 'PF 12%', 'PF 17%',
#        'PF 17% ALC', 'PF 17,5%', 'PF 17,5% ALC', 'PF 18%', 'PF 18% ALC',
#        'PF 20%', 'PMC 0%', 'PMC 12%', 'PMC 17%', 'PMC 17% ALC', 'PMC 17,5%',
#        'PMC 17,5% ALC', 'PMC 18%', 'PMC 18% ALC', 'PMC 20%',
#        'RESTRIÇÃO HOSPITALAR', 'CAP', 'CONFAZ 87', 'ICMS 0%',
#        'ANÁLISE RECURSAL',
#        'LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)',
#        'COMERCIALIZAÇÃO 2020', 'TARJA'],
#       dtype='object')

# %%
#aqui é a descrição do index
medicamentos.index
# Out:
# RangeIndex(start=0, stop=26062, step=1)

# %%
#aqui voce terá uma estatistica
medicamentos.describe
# Out:
# <bound method NDFrame.describe of                                               SUBSTÂNCIA  ...              TARJA
# 0      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  ...         Tarja -(*)
# 1                       DIENOGESTE;VALERATO DE ESTRADIOL  ...  Tarja Vermelha(*)
# 2                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 3                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  ...    Tarja  Vermelha
# 4                                           MONTELUCASTE  ...    Tarja  Vermelha
# ...                                                  ...  ...                ...
# 26057                                    INSULINA HUMANA  ...  Tarja Vermelha(*)
# 26058                                    INSULINA HUMANA  ...    Tarja  Vermelha
# 26059                                ISOCONAZOL;ABARELIX  ...    Tarja  Vermelha
# 26060                                 VALPROATO DE SÓDIO  ...         Tarja -(*)
# ...
