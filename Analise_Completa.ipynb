# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunaMedeiroos/PYTHON-MYSQL-POWER-BI/blob/main/Analise_Completa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de Dados
#
#
# Empresa de telefonia e tem clientes de vários serviços diferentes, entre os principais: internet e telefone.
# Analisando o histórico dos clientes dos últimos anos, você percebeu que a empresa está com perca de mais de 26% dos clientes.

# %%
#passo a passo para o desafio
#Observar o problema
#importar a base de dados e visualizar para ver as informações disponiveis
#descobrir qual é o problema e tratar os dados
#ver se as colunas estao sendo reconhecidos de forma correta
#excluir as colunas irrelevantes
#analise inicial
#analise grafica

# %%
#importando a biblioteca e os dados - dataframe TABELA
import pandas as pd

tabela = pd.read_csv('/content/drive/MyDrive/Analista de Dados/ANALISE/telecom_users.csv')

# %%
#churn significa cancelamento / a não renovação 
tabela
# Out:
#       Unnamed: 0   IDCliente     Genero  ...  TotalGasto Churn Codigo
# 0           1869  7010-BRBUU  Masculino  ...     1734.65   Nao    NaN
# 1           4528  9688-YGXVR   Feminino  ...      3973.2   Nao    NaN
# 2           6344  9286-DOJGF   Feminino  ...     2869.85   Sim    NaN
# 3           6739  6994-KERXL  Masculino  ...       238.5   Nao    NaN
# 4            432  2181-UAESM  Masculino  ...       119.5   Nao    NaN
# ...          ...         ...        ...  ...         ...   ...    ...
# 5981        3772  0684-AOSIH  Masculino  ...          95   Sim    NaN
# 5982        5191  5982-PSMKW   Feminino  ...      2198.3   Nao    NaN
# 5983        5226  8044-BGWPI  Masculino  ...      306.05   Nao    NaN
# 5984        5390  7450-NWRTR  Masculino  ...     1200.15   Sim    NaN
# 5985         860  4795-UXVCJ  Masculino  ...       457.3   Nao    NaN
#
# [5986 rows x 23 columns]

# %%
#aqui estou informando quantas linhas e colunas tem
tabela.shape
# Out:
# (5986, 23)

# %%
#aqui estou informando quais sao as minhas colunas
tabela.columns
# Out:
# Index(['Unnamed: 0', 'IDCliente', 'Genero', 'Aposentado', 'Casado',
#        'Dependentes', 'MesesComoCliente', 'ServicoTelefone', 'MultiplasLinhas',
#        'ServicoInternet', 'ServicoSegurancaOnline', 'ServicoBackupOnline',
#        'ProtecaoEquipamento', 'ServicoSuporteTecnico', 'ServicoStreamingTV',
#        'ServicoFilmes', 'TipoContrato', 'FaturaDigital', 'FormaPagamento',
#        'ValorMensal', 'TotalGasto', 'Churn', 'Codigo'],
#       dtype='object')

# %%
#aqui estou informando o index
tabela.index
# Out:
# RangeIndex(start=0, stop=5986, step=1)

# %%
#excluindo coluna irrelevante - coluna unnamed - coloque dentro do parametro exatamente o nome da coluna que quer excluir
# e o parametro axis, que é o eixo da linha ou da coluna
#para deixar bem claro se é pra excluir linha ou coluna onde 1 é coluna e 0 é linha
tabela = tabela.drop('Unnamed: 0' , axis=1)

# %%
#rodando meu dataframe para visualizar a exclusão da coluna 
tabela
# Out:
#        IDCliente     Genero  Aposentado  ... TotalGasto Churn  Codigo
# 0     7010-BRBUU  Masculino           0  ...    1734.65   Nao     NaN
# 1     9688-YGXVR   Feminino           0  ...     3973.2   Nao     NaN
# 2     9286-DOJGF   Feminino           1  ...    2869.85   Sim     NaN
# 3     6994-KERXL  Masculino           0  ...      238.5   Nao     NaN
# 4     2181-UAESM  Masculino           0  ...      119.5   Nao     NaN
# ...          ...        ...         ...  ...        ...   ...     ...
# 5981  0684-AOSIH  Masculino           0  ...         95   Sim     NaN
# 5982  5982-PSMKW   Feminino           0  ...     2198.3   Nao     NaN
# 5983  8044-BGWPI  Masculino           0  ...     306.05   Nao     NaN
# 5984  7450-NWRTR  Masculino           1  ...    1200.15   Sim     NaN
# 5985  4795-UXVCJ  Masculino           0  ...      457.3   Nao     NaN
#
# [5986 rows x 22 columns]

# %%
#aqui mostra dados mais precisos da tabela, se tem valores vazios
#fala cada coluna e quantos valores nao nulos(preenchidos)
#dtype informa o tipo de valor object(texto) int(numero inteiro) float(numero com casa decimal)
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IDCliente               5986 non-null   object
#  1   Genero                  5986 non-null   object
#  2   Aposentado              5986 non-null   int64
#  3   Casado                  5986 non-null   object
#  4   Dependentes             5985 non-null   object
#  5   MesesComoCliente        5986 non-null   int64
#  6   ServicoTelefone         5986 non-null   object
#  7   MultiplasLinhas         5986 non-null   object
#  8   ServicoInternet         5986 non-null   object
#  9   ServicoSegurancaOnline  5986 non-null   object
#  10  ServicoBackupOnline     5986 non-null   object
#  11  ProtecaoEquipamento     5986 non-null   object
#  12  ServicoSuporteTecnico   5986 non-null   object
#  13  ServicoStreamingTV      5986 non-null   object
#  14  ServicoFilmes           5986 non-null   object
#  15  TipoContrato            5986 non-null   object
#  16  FaturaDigital           5986 non-null   object
#  17  FormaPagamento          5986 non-null   object
#  18  ValorMensal             5986 non-null   float64
#  19  TotalGasto              5986 non-null   object
#  20  Churn                   5985 non-null   object
#  21  Codigo                  0 non-null      float64
# dtypes: float64(2), int64(2), object(18)
# memory usage: 1.0+ MB
# None

# %%
#aqui estou selecionando a coluna para concertar seu valor
#a coluna 19 informa que é object enquanto ela é um numero
#este comando pega a informação dentro do parentese e transforma em numero
#este parametro errors mostra que pode ter erros, e se encontrar , deleta a informação
tabela['TotalGasto'] = pd.to_numeric(tabela["TotalGasto"], errors='coerce')

# %%
#rodando novamente a tabela
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IDCliente               5986 non-null   object
#  1   Genero                  5986 non-null   object
#  2   Aposentado              5986 non-null   int64
#  3   Casado                  5986 non-null   object
#  4   Dependentes             5985 non-null   object
#  5   MesesComoCliente        5986 non-null   int64
#  6   ServicoTelefone         5986 non-null   object
#  7   MultiplasLinhas         5986 non-null   object
#  8   ServicoInternet         5986 non-null   object
#  9   ServicoSegurancaOnline  5986 non-null   object
#  10  ServicoBackupOnline     5986 non-null   object
#  11  ProtecaoEquipamento     5986 non-null   object
#  12  ServicoSuporteTecnico   5986 non-null   object
#  13  ServicoStreamingTV      5986 non-null   object
#  14  ServicoFilmes           5986 non-null   object
#  15  TipoContrato            5986 non-null   object
#  16  FaturaDigital           5986 non-null   object
#  17  FormaPagamento          5986 non-null   object
#  18  ValorMensal             5986 non-null   float64
#  19  TotalGasto              5976 non-null   float64
#  20  Churn                   5985 non-null   object
#  21  Codigo                  0 non-null      float64
# dtypes: float64(3), int64(2), object(17)
# memory usage: 1.0+ MB
# None

# %%
#tratando valores vazios - deletando a linha vazia / deletando a coluna vazia
#nesse comando vc pode deletar varias colunas vazias, com o parametro how 
#e axis- all é o parametro pra deletar todas as colunas vazias // quando tem nAN na tabela, siguinifica que nao foi preenchido
#parametro 'any' siguinifica querer deletar uma coluna com algum valor vazio, pelo menos 1
#axis =  0 - significa coluna // axis =  1 - significa linha
#primeira linha excluindo coluna vazia irrelevante
#segunda linha excluindo linhas vazias da tabela -
tabela = tabela.dropna(how='all', axis=1)
tabela = tabela.dropna(how='any', axis=0)

# %%
#verificando se todos os valores estao iguais
#e as colunas e linhas vazias foram deletadas
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5974 entries, 0 to 5985
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IDCliente               5974 non-null   object
#  1   Genero                  5974 non-null   object
#  2   Aposentado              5974 non-null   int64
#  3   Casado                  5974 non-null   object
#  4   Dependentes             5974 non-null   object
#  5   MesesComoCliente        5974 non-null   int64
#  6   ServicoTelefone         5974 non-null   object
#  7   MultiplasLinhas         5974 non-null   object
#  8   ServicoInternet         5974 non-null   object
#  9   ServicoSegurancaOnline  5974 non-null   object
#  10  ServicoBackupOnline     5974 non-null   object
#  11  ProtecaoEquipamento     5974 non-null   object
#  12  ServicoSuporteTecnico   5974 non-null   object
#  13  ServicoStreamingTV      5974 non-null   object
#  14  ServicoFilmes           5974 non-null   object
#  15  TipoContrato            5974 non-null   object
#  16  FaturaDigital           5974 non-null   object
#  17  FormaPagamento          5974 non-null   object
#  18  ValorMensal             5974 non-null   float64
#  19  TotalGasto              5974 non-null   float64
#  20  Churn                   5974 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.0+ MB
# None

# %%
#analizando - como estao os cancelamentos -
#aqui vou avaliar a coluna CHURN e ver quantos disseram sim e quantos disseram nao para o cancelamento
#nesse parametro irá contar os valores - quantos disseram sim e quantos disseram nao

print(tabela['Churn'].value_counts())
# Out:
# Nao    4387
# Sim    1587
# Name: Churn, dtype: int64

# %%
#vendo em percentual
#normalizar a coluna é calcular o percentual da coluna
#26% cancelaram e 73%nao cancelaram
print(tabela["Churn"].value_counts(normalize=True))
# Out:
# Nao    0.734349
# Sim    0.265651
# Name: Churn, dtype: float64

# %%
#26% equivale a 1587 cancelamentos
#formatar valores em percentual - parametro .map e o parametro que voce quer ver, sempre dentro dos parenteses e colchetes

print(tabela["Churn"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Nao    73.4%
# Sim    26.6%
# Name: Churn, dtype: object

# %%
#aqui estou dizendo quantos sao homens e quantos sao mulheres em numero e em porcentagem
print(tabela["Genero"].value_counts())
print(tabela["Genero"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Masculino    3043
# Feminino     2931
# Name: Genero, dtype: int64
# Masculino    50.9%
# Feminino     49.1%
# Name: Genero, dtype: object

# %%
#comparar cada coluna da tabela com a coluna de cancelamento usando grafico
#comando para importar uma biblioteca especifica
#primeiro voce cria o grafico, depois exibe - o eixo x, quer dizer quem voce quer exibir no grafico
import plotly.express as px

# %%
grafico = px.histogram(tabela, x="MesesComoCliente")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="
"Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Sim", "Sim", "Sim", "Sim", "Sim", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Sim", "Sim", "Sim", "Nao", "Nao", "Sim", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Sim", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Sim", "Sim", "Nao", "Sim", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Sim", "Nao", "Sim", "Nao", "Sim", "Nao", "Sim", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao ...

# %%
#aqui mostra a relação dos meses como cliente e a coluna de cancelamento. 
#da pra observar quanto tempo depois houve o cancelamento
#voce observa que o maior numero de cancelamento está nos contratos mais recentes, ou seja, nos primeiros meses
grafico = px.histogram(tabela, x="MesesComoCliente", color="Churn")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b98a87d8-f89a-450b-b0fa-f00db406cc9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b98a87d8-f89a-450b-b0fa-f00db406cc9b")) {
#                     Plotly.newPlot(
#                         'b98a87d8-f89a-450b-b0fa-f00db406cc9b',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Churn=Nao<br>MesesComoCliente=%{x}<br>count=%{y}", "legendgroup": "Churn=Nao", "marker": {"color": "#636efa"}, "name": "Churn=Nao", "offsetgroup": "Churn=Nao", "orientation": "v", "showlegend": true, "type": "histogram", "x": [72, 44, 4, 2, 70, 33, 1, 39, 55, 52, 60, 50, 32, 51, 1, 52, 62, 72, 72, 1, 63, 67, 40, 65, 16, 46, 11, 49, 68, 10, 2, 5, 53, 54, 10, 71, 8, 64, 57, 20, 26, 32, 5, 70, 1, 35, 6, 72, 13, 4, 63, 71, 15, 30, 23, 9, 35, 6, 72, 45, 70, 53, 72, 72, 17, 7, 72, 11, 30, 11, 17, 34, 55, 5, 11, 70, 35, 58, 72, 68, 26, 12, 25, 72, 70, 26, 28, 6, 58, 29, 16, 52, 72, 71, 65, 49, 52, 71, 54, 15, 9, 50, 70, 72, 52, 15, 72, 58, 1, 35, 41, 72, 30, 37, 72, 72, 70, 23, 8, 26, 52, 23, 40, 27, 37, 45, 71, 38, 3, 17, 70, 1, 71, 37, 64, 37, 23, 26, 60, 71, 58, 71, 2, 40, 68, 57, 70, 68, 52, 72, 67, 68, 23, 1, 71, 69, 18, 69, 62, 56, 7, 1, 6, 16, 2, 72, 7, 19, 14, 25, 70, 66, 53, 59, 24, 31, 1, 12, 2, 48, 71, 56, 2, 50, 63, 6, 5, 71, 42, 64, 1, 69, 33, 20, 13, 28, 72, 9, 72, 52, 34, 71, 6, 31, 49, 27, 53, 46, 35, 9, 64, 55, 51, 5, 23, 61, 54, 64, 18, 52, 17, 27, 58, 68, 1
72, 8, 32, 56, 44, 4, 36, 2, 52, 64, 2, 8, 60, 20, 22, 54, 1, 13, 24, 6, 38, 12, 26, 6, 50, 72, 72, 51, 1, 60, 24, 67, 69, 67, 67, 27, 41, 64, 72, 70, 71, 3, 63, 25, 62, 55, 52, 29, 8, 5, 9, 72, 7, 18, 48, 71, 69, 60, 1, 38, 4, 31, 14, 71, 64, 9, 56, 11, 72, 1, 60, 33, 72, 26, 22, 22, 27, 32, 41, 56, 1, 1, 34, 64, 7, 51, 21, 21, 57, 8, 18, 35, 32, 30, 26, 38, 34, 55, 57, 66, 43, 32, 1, 40, 41, 30, 54, 7, 58, 52, 26, 34, 53, 15, 5, 34, 32, 41, 25, 17, 17, 70, 43, 71, 49, 72, 26, 18, 28, 60, 23, 29, 56, 11, 27, 66, 2, 19, 62, 51, 72, 37, 35, 10, 26, 72, 56, 36, 22, 65, 27, 29, 50, 9, 23, 1, 20, 47, 72, 14, 62, 29, 62, 46, 50, 55, 64, 6, 37, 71, 29, 32, 59, 40, 27, 65, 23, 47, 11, 12, 30, 57, 11, 9, 13, 35, 67, 51, 71, 29, 11, 13, 42, 8, 72, 47, 30, 51, 16, 34, 72, 60, 72, 12, 65, 32, 45, 60,  ...

# %%
#aqui estou relacionando o tipo de contrato com a coluna cancelamento
#observe que o maior numero de cancelamento é no tipo de contrato mensal
grafico = px.histogram(tabela, x="TipoContrato", color="Churn")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cd3ffc23-ba3b-436e-9c14-2079c3c94581" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd3ffc23-ba3b-436e-9c14-2079c3c94581")) {
#                     Plotly.newPlot(
#                         'cd3ffc23-ba3b-436e-9c14-2079c3c94581',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Churn=Nao<br>TipoContrato=%{x}<br>count=%{y}", "legendgroup": "Churn=Nao", "marker": {"color": "#636efa"}, "name": "Churn=Nao", "offsetgroup": "Churn=Nao", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["2 anos", "Mensal", "Mensal", "Mensal", "2 anos", "Mensal", "Mensal", "Anual", "Mensal", "Anual", "Mensal", "Anual", "Anual", "Anual", "Mensal", "2 anos", "2 anos", "2 anos", "2 anos", "Mensal", "2 anos", "2 anos", "Mensal", "Anual", "2 anos", "Anual", "Mensal", "Mensal", "Anual", "Anual", "Mensal", "Mensal", "Anual", "2 anos", "Mensal", "2 anos", "Mensal", "2 anos", "2 anos", "Mensal", "Mensal", "Anual", "Mensal", "2 anos", "Mensal", "Anual", "Mensal", "2 anos", "Anual", "Mensal", "2 anos", "2 anos", "Mensal", "2 anos", "Mensal", "Anual", "Anual", "Mensal", "2 anos", "2 anos", "2 anos", "2 anos", "2 anos", "2 anos", "Mensal", "Mensal", "2 anos", "Mensal", "Mensal", "2 anos", "Mensal", "Mensal", "Anual", "Mensal", "Anual", "2 anos", "2 anos", "Anual", "2 anos", "2 anos", "Anual", "Mensal", "Mensal", "2 anos", "2 anos", "Mensal", "Anual", "Mensal", "2 anos", "Mensal", "Mensal", "Anual", "2 anos", "2 anos", "2 anos", "Mensal", "Mensal", "2 anos", "Mensal", "Mensal", "Mensal", "2 anos", "2 anos", "Anual", "Anual", "Mensal", "2 anos", "Anual", "Mensal", "Mensal", "2
 3462.1, 45.3, 6096.45, 298.7, 5985.75, 4576.3, 1329.15, 1265.65, 2495.2, 532.1, 490.65, 147.8, 5064.45, 934.8, 760.05, 1234.6, 199.85, 6129.65, 1231.85, 1654.75, 4483.95, 413.25, 2564.95, 294.45, 5442.05, 804.25, 1982.6, 1501.75, 2016.45, 7895.15, 4378.8, 5686.4, 329.75, 2960.1, 1336.8, 5129.45, 521.35, 613.95, 1414.65, 219.5, 3062.45, 587.7, 4228.55, 1875.25, 1901.25, 7234.8, 5705.05, 1710.15, 1930.9, 189.1, 7898.45, 6441.85, 5163.0, 2348.45, 429.55, 720.45, 7283.25, 4126.35, 241.3, 1190.5, 160.85, 3721.9, 2651.1, 4014.6, 2344.5, 7379.8, 7862.25, 1108.8, 655.3, 20.2, 2971.7, 981.45, 3171.6, 6555.2, 8309.55, 4192.15, 73.05, 1734.2, 957.1, 447.75, 249.55, 2209.15, 654.85, 789.2, 38.45, 4448.8, 1641.3, 5894.5, 4017.45, 101.1, 1029.8, 74.0, 129.15, 7297.75, 550.6, 1416.5, 601.6, 4534.45, 4236.6, 2203.7, 494.05, 4299.95, 2893.4, 391.7, 1070.5, 58.0, 176.2, 3437.5, 4109.0, 122.7, 317.75, 116.95, 4469.1, 865.1, 2088.45, 7748.75, 6350.5, 162.45, 888.65, 3313.4, 5791.1, 756.4, 1857.75, 1825.5, 159.2, 4124.65, 272.35, 3488.15, 436.9, 5959.3, 4589.85, 5315.1, 712.25, 84.6, 3635.15, 1184.0, 3842.6, 1867.6, 1158.85, 386.5, 2156.25, 1359.45, 257.0, 31.9, 4523.25, 847.25, 62.9, 4929.55, 7181.25, 3399.85, 3107.3, 865.85, 6236.75, 4614.55, 6139.5, 3166.9, 4134.7, 1439.35, 48.6, 109.2, 189.95, 1071.4, 181.8, 832.3, 1837.7, 4917.75, 184.95, 3314.15, 2460.55, 999.8, 238.5, 7031.3, 4144.8, 3865.6, 3274.35, 1505.45, 2259.35, 433.75, 6066.55, 6869.7, 692.35, 5960.5, 576.65, 5692.65, 4164.4, 4615.25, 3043.6, 3382.3, 6430.9, 3582.4, 20.05, 1181.75, 6590.8, 1988.05, 2830.45, 1087.45, 504.2, 7308.95, 450.65, 1266.35, 1309.0, 962.25, 3605.6, 4040.2, 1344.5, 467.5, 490.55, 1497.05, 214.55, 4300.8, 1189.9, 1188.2, 3094.05, 1348.5, 7173.15, 6747.35, 373.0, 5196.1, 632.2, 5153.5, 777.3, 1621.35, 7616.0, 1665.2, 3580.95, 1790.35, 1706.45, 7511.3, 4526 ...

# %%
print(tabela['ValorMensal'])
print(tabela['TotalGasto'])
# Out:
# 0       24.10
# 1       88.15
# 2       74.95
# 3       55.90
# 4       53.45
#         ...
# 5981    95.00
# 5982    91.10
# 5983    21.15
# 5984    99.45
# 5985    19.80
# Name: ValorMensal, Length: 5974, dtype: float64
# 0       1734.65
# 1       3973.20
# 2       2869.85
# 3        238.50
# 4        119.50
#          ...
# 5981      95.00
# 5982    2198.30
# 5983     306.05
# 5984    1200.15
# 5985     457.30
# Name: TotalGasto, Length: 5974, dtype: float64

# %%
grafico = px.histogram(tabela, x="ServicoInternet", color="Churn")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f024fa51-1888-45c9-bb7a-e317082fc341" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f024fa51-1888-45c9-bb7a-e317082fc341")) {
#                     Plotly.newPlot(
#                         'f024fa51-1888-45c9-bb7a-e317082fc341',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Churn=Nao<br>ServicoInternet=%{x}<br>count=%{y}", "legendgroup": "Churn=Nao", "marker": {"color": "#636efa"}, "name": "Churn=Nao", "offsetgroup": "Churn=Nao", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Nao", "Fibra", "DSL", "DSL", "DSL", "Fibra", "DSL", "DSL", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "Fibra", "Fibra", "Nao", "Fibra", "Nao", "Fibra", "Nao", "Fibra", "DSL", "Fibra", "Fibra", "Nao", "DSL", "DSL", "Fibra", "DSL", "Nao", "Fibra", "Fibra", "DSL", "Fibra", "Nao", "Nao", "DSL", "Fibra", "Nao", "DSL", "DSL", "Fibra", "Nao", "Fibra", "DSL", "DSL", "DSL", "DSL", "Nao", "DSL", "Nao", "Fibra", "Nao", "Nao", "Fibra", "Nao", "Nao", "DSL", "Nao", "DSL", "DSL", "Nao", "DSL", "DSL", "Fibra", "Fibra", "Fibra", "Fibra", "DSL", "Nao", "DSL", "DSL", "Nao", "DSL", "Nao", "Nao", "Nao", "DSL", "Fibra", "DSL", "DSL", "DSL", "DSL", "Fibra", "Fibra", "Fibra", "Nao", "Nao", "DSL", "DSL", "DSL", "DSL", "Fibra", "Nao", "Nao", "Fibra", "Fibra", "Fibra", "Fibra", "DSL", "DSL", "Fibra", "Fibra", "Fibra", "Fibra", "DSL", "DSL", "Fibra", "Nao", "Fibra", "Nao", "DSL", "DSL", "DSL", "DSL", "Nao", "Fibra", "Fibra", "Fibra", "DSL", "Nao", "DSL", "DSL", "DSL", "Nao", "Fibra", "Nao", "Nao", "DSL", "Nao", "DSL", "DSL", "Fibra", "Fibra", "DSL", "Fibra", "DSL", "DSL", "Fibra", "DSL", "Fibra", "DSL", "DSL", "Nao", "Nao", "Fibra", "Fibra", "Fibra", "Fibra", "Fibra", "DSL", "DSL", "Nao", "DSL", "Nao", "Fibra", "Fibra", "DSL", "Fibra", "Nao", "Nao", "Nao", "Nao", "DSL", "Nao", "DSL", "DSL", "DSL", "Fibra", "DSL", "DSL", "Nao", "Fibra", "Fibra", "Nao", "Fibra", "DSL", "DSL", "Nao", "DSL", "DSL", "Nao", "Nao", "Nao", "Fibra", "DSL", "DSL", "Fibra", "DSL", "Nao", "DSL", "Fibra", "Fibra", "Nao", "Nao", "DSL", "DSL", "Fibra", "Fibra", "DSL", "DSL", "Fibra", "Nao", "DSL", "Nao", "Nao", "Fibra", "DSL", "Nao", "Fibra", "Fibra", "Fibra", "Fibra", "Nao", "Nao", "Fibra", "DSL", "Nao", "DSL", "Fibra", "Nao", "Nao", "Fibra", "Fibra", "Nao", "DSL", "DSL", "DSL", "DSL", "Fibra", "DSL", "Fibra", "DSL", "DSL", "Nao", "Nao", "DSL", "DSL", "DSL", "Fibra", "Nao", "Fibra", "DSL", "DSL", "Nao", "Fibra", "Fibra", "DSL", "Fibra", "DSL", "Nao", "DSL", "Nao", "DSL", "Fibra", "DSL", "Fibra", "Nao", "DSL", "DSL", "Fibra", "Fibra", "Nao", "Nao", "Nao", "DSL", "Nao", "Fibra", "DSL", "DSL", "Fibra", "DSL", "Nao", "DSL", "DSL", "Fibra", "DSL", "DSL", "DSL", "Nao", "Fibra", "Fibra", "Fibra", "Fibra", "DSL", "DSL", "DSL", "Fibra", "Fibra", "DSL", "Fibra", "Fibra", "Nao", "Nao", "Nao", "Fibra", "DSL", "DSL", "Fibra", "Fibra", "Fibra", "Nao", "DSL", "DSL", "DSL", "DSL", "DSL", "Nao", "DSL", "DSL", "DSL", "Fibra", "DSL", "DSL", "DSL", "Nao", "Fibra", "Nao", "Fibra", "Fibra", "Nao", "Nao", "DSL", "Fibra", "Fibra", "Nao", "DSL", "DSL", "Nao", "Nao", "Nao", "DSL", "Fibra", "DSL", "DSL", "Fibra", "Nao", "Fibra", "Fibra", "Fibra", "Fibra", "DSL", "DSL", "Fibra", "Fibra", "Fibra", "Nao", "Fibra", "DSL", "Nao", "DSL", "Nao", "Fibra", "Nao", "DSL", "Fibra", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "Fibra", "DSL", "Nao", "Nao", "DSL", "Fibra", "Nao", "Nao", "DSL", "Nao", "Nao", "DSL", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "Fibra", "Fibra", "DSL", "DSL", "DSL", "DSL", "Nao", "DSL", "DSL", "Nao", "DSL", "DSL", "Fibra", "Nao", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "Fibra", "Nao", "Fibra", "Fibra", "DSL", "Fibra", "Nao", "Fibra", "DSL", "Fibra", "DSL", "Fibra", "Fibra", "DSL", "Nao", "DSL", "Fibra", "Nao", "Fibra", "DSL", "Nao", "Fibra", "Nao", "DSL", "DSL", "Nao", "Fibra", "Fibra", "Nao", "Nao", "Fibra", "DSL", "DSL", "DSL", "Nao", "Nao", "DSL", "DSL", "Fibra", "Fibra", "DSL", "DSL", "Fibra", "Fibra", "Fibra", "DSL", "Fibra", "DSL", "DSL", "Nao", "Fibra", "Fibra", "Fibra", "Fibra", "Nao", "Fibra", "DSL", "Fibra", "Nao", "Fibra", "Fibra", "DSL", "Nao", "Nao", "Fibra", "DSL", "DSL", "Nao", "Fibra", "DSL", "DSL", "Nao", "DSL", "F ...

# %%
#Cliente com contrato mensal tem muito mais chance de cancelar
#podemos fazer promoçoes para esses clientes irem para o contrato anual, onde a taxa é bem menor
#Cliente mais novos estao cancelando
#observe que o cliente mais recentes ou ate 10 meses e com mais gastos estao cancelando, tente oferecer um pacote promocional e mais viavel
#A primeira experiencia do cliente na operadora pode ser ruim
#servoço de internet canvelam mais
#talvez a captação de clientes está trazendo clientes desqualicados
#criar incentivo para o cliente ficar mais tempo na operadora/ fidelizar

# %%
#aqui eu importei minha tabela ja tratada para a maquina local em csv
tabela.to_csv('telefonia.csv')

# %%
#aqui importei minha tabela ja tratada em xlsx para levar ao Power Bi
tabela.to_excel('tabela.xlsx')
